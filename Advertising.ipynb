# %% [markdown]
# <a href="https://colab.research.google.com/github/Godvampire07/ML/blob/main/Advertising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #data preprocessing
import numpy as np #linear algebra
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sns.scatterplot(x = df['TV'] ,y = df['Sales'])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
#pred = y_pred
new_data = pd.DataFrame({"TV": [44.1], "Radio": [29.2] , "Newspaper": [30.6]})
prediction = model.predict(new_data)
print("Prediction:", prediction)
# Out:
# Prediction: [10.28960489]

# %%
mean_squared_error(y_test,y_pred)
r2_score
# Out:
# 4.522552562041291
